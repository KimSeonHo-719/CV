# %% [markdown]
# <a href="https://colab.research.google.com/github/KimSeonHo-719/CV/blob/main/Assignment_4_Q5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q5.
# - 채널: 3채널 -> 4채널 => 채널 수 512까지 확장
# -> 4개의 컨볼루션 블록으로 깊이를 늘리고, 채널 수도 3->64->128->256->512 순으로 단계적으로 확장
# - BatchNorm2d
# -> 학습 안정성, 수렴 속도 향상
# - MaxPool2d, Adaptive Average Pool2d
# -> 3번의 MaxPool2d로 해상도 축소 (32->16->8->4)
# -> 마지막에 Global Average Pooling 거쳐서 feature map 1x1로 파라미터 절감
# - Flatten -> Linear(512->128) -> ReLU -> Dropout(0.5) -> Linear(128->10): Classifier 개선
# -> Hidden Layer(128) 추가하여 비선형 분류 성능 향상
# -> Dropout으로 오버피팅 억제
# - Data Augmentation
# -> 가상의 더 큰 데이터셋으로 학습하여 일반화 성능 향상
# - learning rate: 0.001->0.01, batch: 16->64, epoch: 50->100 증가
# -> 더 높은 학습률로 빠른 수렴 유도
# -> 충분히 긴 학습으로 안정적 수렴
# -> 배치 수를 더 크게 하여 배치 정규화 효과 극대화

# %%
# Q5.
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from tqdm import tqdm

train_batch_size = 64
test_batch_size  = 256

# 1. 데이터셋 준비 (Augmentation 적용)
# (1) 테스트 세트용 Transform (Augmentation 없이 평소대로)
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
])

# (2) 학습 세트용 Transform (여기에만 Augmentation 추가)
train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),              # 1) RandomCrop + padding
    transforms.RandomHorizontalFlip(p=0.5),            # 2) RandomHorizontalFlip
    transforms.ColorJitter(brightness=0.2,             # 3) ColorJitter
                           contrast=0.2,
                           saturation=0.2,
                           hue=0.1),
    transforms.RandomRotation(degrees=15),             # 4) RandomRotation
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
])

# 데이터셋·로더 생성
train_set = torchvision.datasets.CIFAR10(root='./data',
                                         train=True,
                                         download=True,
                                         transform=train_transform)
test_set  = torchvision.datasets.CIFAR10(root='./data',
                                         train=False,
                                         download=True,
                                         transform=test_transform)

train_loader = DataLoader(train_set, batch_size=train_batch_size, shuffle=True,  num_workers=4)
test_loader  = DataLoader(test_set,  batch_size=test_batch_size, shuffle=False, num_workers=4)

# 학습용 이미지를 무작위로 가져오기
dataiter = iter(train_loader)
images, labels = next(dataiter)

# 이미지 보여주기 함수 정의
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# CIFAR10 클래스 이름 정의
classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# 이미지 보여주기
imshow(torchvision.utils.make_grid(images))
# 정답(label) 출력
print(' '.join(f'{classes[labels[j]]:5s}' for j in range(train_batch_size)))

# 2. CNN 모델 정의
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.features = nn.Sequential(
            # Conv->Pool (3->64)
            nn.Conv2d(3, 64, 3, padding=1),
            nn.BatchNorm2d(64), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),

            # Conv->Pool (64->128)
            nn.Conv2d(64, 128, 3, padding=1),
            nn.BatchNorm2d(128), nn.ReLU(inplace=True),


            # Conv->Pool (128->256)
            nn.Conv2d(128, 256, 3, padding=1),
            nn.BatchNorm2d(256), nn.ReLU(inplace=True),
            nn.MaxPool2d(2),

            # Conv->Pool (256->512)
            nn.Conv2d(256, 512, 3, padding=1),
            nn.BatchNorm2d(512), nn.ReLU(inplace=True),
            # Global Average Pooling
            nn.AdaptiveAvgPool2d((1, 1))
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),                  # → [B, 64]
            nn.Linear(512,128),
            nn.ReLU(inplace=True),
            # Dropout(0.5) 추가 -> 오버피팅 방지
            nn.Dropout(0.5),
            nn.Linear(128,10)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.classifier(x)
        return x

# 3. 학습 함수
def train(model, loader, criterion, optimizer, device):
    model.train()
    total_loss = 0
    for inputs, targets in tqdm(loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(loader)

# 4. 평가 함수
def evaluate(model, loader, device):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, targets in loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            preds = torch.argmax(outputs, dim=1)
            correct += (preds == targets).sum().item()
            total += targets.size(0)
    return correct / total

# 5. 학습
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = CNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

num_epochs = 100
for epoch in range(num_epochs):
    train_loss = train(model, train_loader, criterion, optimizer, device)
    test_acc = evaluate(model, test_loader, device)
    print(f"Epoch {epoch+1}: Train Loss = {train_loss:.4f}, Test Acc = {test_acc:.4f}")
# Out:
# plane truck ship  dog   truck plane frog  frog  car   cat   truck horse truck deer  truck frog  ship  bird  deer  bird  frog  horse truck ship  car   car   plane car   deer  ship  frog  ship  plane horse frog  truck bird  plane car   plane cat   cat   bird  horse frog  truck horse plane car   deer  car   frog  cat   horse truck frog  bird  car   deer  dog   bird  truck ship  dog
# 100%|██████████| 782/782 [00:43<00:00, 18.18it/s]
# Epoch 1: Train Loss = 1.7121, Test Acc = 0.4050
# 100%|██████████| 782/782 [00:43<00:00, 17.81it/s]
# Epoch 2: Train Loss = 1.4094, Test Acc = 0.5579
# 100%|██████████| 782/782 [00:43<00:00, 18.17it/s]
# Epoch 3: Train Loss = 1.2751, Test Acc = 0.6092
# 100%|██████████| 782/782 [00:44<00:00, 17.76it/s]
# Epoch 4: Train Loss = 1.1915, Test Acc = 0.5954
# 100%|██████████| 782/782 [00:43<00:00, 18.05it/s]
# Epoch 5: Train Loss = 1.1248, Test Acc = 0.6331
# 100%|██████████| 782/782 [00:44<00:00, 17.63it/s]
# Epoch 6: Train Loss = 1.0674, Test Acc = 0.6670
# ...
